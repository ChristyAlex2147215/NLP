# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristyAlex2147215/NLP/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
# %cd drive/MyDrive/NLP/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/NLP/'
# /content/drive/MyDrive/NLP

# %%
# !ls
# Out:
# 'lab_1_2147215 (1).ipynb'   Lab1.ipynb	 Lab2.ipynb   NLP_dataset

# %%
nltk.download("all", download_dir="NLP_dataset")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to NLP_dataset...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to NLP_dataset...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to NLP_dataset...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to NLP_dataset...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to NLP_dataset...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to NLP_dataset...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to NLP_dataset...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to NLP_dataset...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to NLP_dataset...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to NLP_dataset...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to NLP_dataset...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to NLP_dataset...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to NLP_dataset...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to NLP_dataset...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to NLP_dataset...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to NLP_dataset...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to NLP_dataset...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to NLP_dataset...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to NLP_dataset...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to NLP_dataset...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to NLP_dataset...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to NLP_dataset...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to NLP_dataset...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to NLP_dataset...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to NLP_dataset...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to NLP_dataset...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to NLP_dataset...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to NLP_dataset...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to NLP_dataset...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to NLP_dataset...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to NLP_dataset...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to NLP_dataset...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to NLP_dataset...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to NLP_dataset...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to NLP_dataset...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to NLP_dataset...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to NLP_dataset...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to NLP_dataset...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to NLP_dataset...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to NLP_dataset...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to NLP_dataset...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to NLP_dataset...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to NLP_dataset...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to NLP_dataset...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to NLP_dataset...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to NLP_dataset...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to NLP_dataset...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to NLP_dataset...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to NLP_dataset...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to NLP_dataset...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to NLP_dataset...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to NLP_dataset...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to NLP_dataset...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to NLP_dataset...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to NLP_dataset...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to NLP_dataset...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to NLP_dataset...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to NLP_dataset...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to NLP_dataset...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to NLP_dataset...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to NLP_dataset...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to NLP_dataset...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to NLP_dataset...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to NLP_dataset...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to NLP_dataset...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to NLP_dataset...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to NLP_dataset...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to NLP_dataset...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to NLP_dataset...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to NLP_dataset...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to NLP_dataset...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to NLP_dataset...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to NLP_dataset...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to NLP_dataset...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to NLP_dataset...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to NLP_dataset...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to NLP_dataset...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to NLP_dataset...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to NLP_dataset...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to NLP_dataset...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to NLP_dataset...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to NLP_dataset...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to NLP_dataset...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to NLP_dataset...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to NLP_dataset...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     NLP_dataset...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to NLP_dataset...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to NLP_dataset...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to NLP_dataset...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to NLP_dataset...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to NLP_dataset...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to NLP_dataset...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to NLP_dataset...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to NLP_dataset...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to NLP_dataset...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to NLP_dataset...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to NLP_dataset...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to NLP_dataset...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from nltk.corpus import abc

# %%
dataset="""Police: I understand you were the key witness for the robbery.

Woman: Yes, I was the only other person in the bank besides the tellers.

Police: Are you okay to answer some questions for me?

Woman: Sure. I don't know how much help I'll be. He made me get on the ground so I didn't get a very good look at him.

Police: Was he carrying a weapon?

Woman: Yes, he had a pistol in his back pocket. He threatened to use it, but I doubt it was loaded.

Police: What makes you say that?

Woman: He was just a kid. Probably fifteen or younger.

Police: Can you describe him for me?

Woman: He was Asian. Probably five foot six. He was wearing a baseball cap and sunglasses. I can't remember what else he was wearing.

Police: Did he talk directly to you? I mean, did he ask you for your money or anything?

Woman: No, he just told me to get on the ground. That's all I know. I'm running late for a class. Is it okay if I go now?

Police: I just want to get your name and phone number. If you think of anything else, please notify us.
"""

# %%
type(dataset)
# Out:
# str

# %% [markdown]
# #Token using split

# %%
token_split=dataset.split()
token_split
# Out:
# ['Police:',
#  'I',
#  'understand',
#  'you',
#  'were',
#  'the',
#  'key',
#  'witness',
#  'for',
#  'the',
#  'robbery.',
#  'Woman:',
#  'Yes,',
#  'I',
#  'was',
#  'the',
#  'only',
#  'other',
#  'person',
#  'in',
#  'the',
#  'bank',
#  'besides',
#  'the',
#  'tellers.',
#  'Police:',
#  'Are',
#  'you',
#  'okay',
#  'to',
#  'answer',
#  'some',
#  'questions',
#  'for',
#  'me?',
#  'Woman:',
#  'Sure.',
#  'I',
#  "don't",
#  'know',
#  'how',
#  'much',
#  'help',
#  "I'll",
#  'be.',
#  'He',
#  'made',
#  'me',
#  'get',
#  'on',
#  'the',
#  'ground',
#  'so',
#  'I',
#  "didn't",
#  'get',
#  'a',
#  'very',
#  'good',
#  'look',
#  'at',
#  'him.',
#  'Police:',
#  'Was',
#  'he',
#  'carrying',
#  'a',
#  'weapon?',
#  'Woman:',
#  'Yes,',
#  'he',
#  'had',
#  'a',
#  'pistol',
#  'in',
#  'his',
#  'back',
#  'pocket.',
#  'He',
#  'threatened',
#  'to',
#  'use',
#  'it,',
#  'but',
#  'I',
#  'doubt',
#  'it',
#  'was',
#  'loaded.',
#  'Police:',
#  'What',
#  'makes',
#  'you',
#  'say',
#  'that?',
#  'Woman:',
#  'He',
#  'was',
#  'just',
#  'a',
#  'kid.',
#  'Probably',
#  'fifteen',
#  'or',
#  'younger.',
#  'Police:',
#  'Can',
#  'you',
#  'describe',
#  'him',
#  'for',
#  'me?',
#  'Woman:',
#  'He',
#  'was',
#  'Asian.',
#  'Probably',
#  'five',
#  'foot',
#  'six.',
#  'He',
#  'was',
#  'wearing',
#  'a',
#  'baseball',
#  'cap',
#  'and',
#  'sunglasses.',
#  'I',
#  "can't",
#  'remember',
#  'what',
#  'else',
#  'he',
#  'was',
#  'wearing.',
#  'Police:',
#  'Did',
#  'he',
#  'talk',
#  'directly',
#  'to',
#  'you?',
#  'I',
#  'mean,',
#  'did',
#  'he',
#  'ask',
#  'you',
#  'for',
#  'your',
#  'money',
#  'or',
#  'anything?',
#  'Woman:',
#  'No,',
#  'he',
#  'just',
#  'told',
#  'me',
#  'to',
#  'get',
#  'on',
#  'the',
#  'ground.',
#  "That's",
#  'all',
#  'I',
#  'know.',
#  "I'm",
#  'running',
#  'late',
#  'for',
#  'a',
#  'class.',
#  'Is',
#  'it',
#  'okay',
#  'if',
#  'I',
#  'go',
#  'now?',
#  'Police:',
#  'I',
#  'just',
#  'want',
#  'to',
#  'get',
#  'your',
#  'name',
#  'and',
#  'phone',
#  'number.',
#  'If',
#  'you',
#  'think',
#  'of',
#  'anything',
#  'else,',
#  'please',
#  'notify',
#  'us.']

# %% [markdown]
# #tokenization using word_token and  sent_token

# %%
from nltk.tokenize import sent_tokenize as st,word_tokenize as wt

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
dataset_st=st(dataset)
dataset_st
# Out:
# ['Police: I understand you were the key witness for the robbery.',
#  'Woman: Yes, I was the only other person in the bank besides the tellers.',
#  'Police: Are you okay to answer some questions for me?',
#  'Woman: Sure.',
#  "I don't know how much help I'll be.",
#  "He made me get on the ground so I didn't get a very good look at him.",
#  'Police: Was he carrying a weapon?',
#  'Woman: Yes, he had a pistol in his back pocket.',
#  'He threatened to use it, but I doubt it was loaded.',
#  'Police: What makes you say that?',
#  'Woman: He was just a kid.',
#  'Probably fifteen or younger.',
#  'Police: Can you describe him for me?',
#  'Woman: He was Asian.',
#  'Probably five foot six.',
#  'He was wearing a baseball cap and sunglasses.',
#  "I can't remember what else he was wearing.",
#  'Police: Did he talk directly to you?',
#  'I mean, did he ask you for your money or anything?',
#  'Woman: No, he just told me to get on the ground.',
#  "That's all I know.",
#  "I'm running late for a class.",
#  'Is it okay if I go now?',
#  'Police: I just want to get your name and phone number.',
#  'If you think of anything else, please notify us.']

# %% [markdown]
# #word tokenizer

# %%
dataset_wt=wt(dataset)
dataset_wt
# Out:
# ['Police',
#  ':',
#  'I',
#  'understand',
#  'you',
#  'were',
#  'the',
#  'key',
#  'witness',
#  'for',
#  'the',
#  'robbery',
#  '.',
#  'Woman',
#  ':',
#  'Yes',
#  ',',
#  'I',
#  'was',
#  'the',
#  'only',
#  'other',
#  'person',
#  'in',
#  'the',
#  'bank',
#  'besides',
#  'the',
#  'tellers',
#  '.',
#  'Police',
#  ':',
#  'Are',
#  'you',
#  'okay',
#  'to',
#  'answer',
#  'some',
#  'questions',
#  'for',
#  'me',
#  '?',
#  'Woman',
#  ':',
#  'Sure',
#  '.',
#  'I',
#  'do',
#  "n't",
#  'know',
#  'how',
#  'much',
#  'help',
#  'I',
#  "'ll",
#  'be',
#  '.',
#  'He',
#  'made',
#  'me',
#  'get',
#  'on',
#  'the',
#  'ground',
#  'so',
#  'I',
#  'did',
#  "n't",
#  'get',
#  'a',
#  'very',
#  'good',
#  'look',
#  'at',
#  'him',
#  '.',
#  'Police',
#  ':',
#  'Was',
#  'he',
#  'carrying',
#  'a',
#  'weapon',
#  '?',
#  'Woman',
#  ':',
#  'Yes',
#  ',',
#  'he',
#  'had',
#  'a',
#  'pistol',
#  'in',
#  'his',
#  'back',
#  'pocket',
#  '.',
#  'He',
#  'threatened',
#  'to',
#  'use',
#  'it',
#  ',',
#  'but',
#  'I',
#  'doubt',
#  'it',
#  'was',
#  'loaded',
#  '.',
#  'Police',
#  ':',
#  'What',
#  'makes',
#  'you',
#  'say',
#  'that',
#  '?',
#  'Woman',
#  ':',
#  'He',
#  'was',
#  'just',
#  'a',
#  'kid',
#  '.',
#  'Probably',
#  'fifteen',
#  'or',
#  'younger',
#  '.',
#  'Police',
#  ':',
#  'Can',
#  'you',
#  'describe',
#  'him',
#  'for',
#  'me',
#  '?',
#  'Woman',
#  ':',
#  'He',
#  'was',
#  'Asian',
#  '.',
#  'Probably',
#  'five',
#  'foot',
#  'six',
#  '.',
#  'He',
#  'was',
#  'wearing',
#  'a',
#  'baseball',
#  'cap',
#  'and',
#  'sunglasses',
#  '.',
#  'I',
#  'ca',
#  "n't",
#  'remember',
#  'what',
#  'else',
#  'he',
#  'was',
#  'wearing',
#  '.',
#  'Police',
#  ':',
#  'Did',
#  'he',
#  'talk',
#  'directly',
#  'to',
#  'you',
#  '?',
#  'I',
#  'mean',
#  ',',
#  'did',
#  'he',
#  'ask',
#  'you',
#  'for',
#  'your',
#  'money',
#  'or',
#  'anything',
#  '?',
#  'Woman',
#  ':',
#  'No',
#  ',',
#  'he',
#  'just',
#  'told',
#  'me',
#  'to',
#  'get',
#  'on',
#  'the',
#  'ground',
#  '.',
#  'That',
#  "'s",
#  'all',
#  'I',
#  'know',
#  '.',
#  'I',
#  "'m",
#  'running',
#  'late',
#  'for',
#  'a',
#  'class',
#  '.',
#  'Is',
#  'it',
#  'okay',
#  'if',
#  'I',
#  'go',
#  'now',
#  '?',
#  'Police',
#  ':',
#  'I',
#  'just',
#  'want',
#  'to',
#  'get',
#  'your',
#  'name',
#  'and',
#  'phone',
#  'number',
#  '.',
#  'If',
#  'you',
#  'think',
#  'of',
#  'anything',
#  'else',
#  ',',
#  'please',
#  'notify',
#  'us',
#  '.']

# %% [markdown]
# #weetTokenizer

# %%
from nltk.tokenize import TweetTokenizer

# %%
dataset_tt=TweetTokenizer().tokenize(dataset)

# %%
dir(dataset_tt)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# #

# %%
import nltk.data
tokenizer=nltk.data.load("tokenizers/punkt/PY3/english.pickle")
tokenizer

tokenizer.tokenize(dataset)
# Out:
# ['Police: I understand you were the key witness for the robbery.',
#  'Woman: Yes, I was the only other person in the bank besides the tellers.',
#  'Police: Are you okay to answer some questions for me?',
#  'Woman: Sure.',
#  "I don't know how much help I'll be.",
#  "He made me get on the ground so I didn't get a very good look at him.",
#  'Police: Was he carrying a weapon?',
#  'Woman: Yes, he had a pistol in his back pocket.',
#  'He threatened to use it, but I doubt it was loaded.',
#  'Police: What makes you say that?',
#  'Woman: He was just a kid.',
#  'Probably fifteen or younger.',
#  'Police: Can you describe him for me?',
#  'Woman: He was Asian.',
#  'Probably five foot six.',
#  'He was wearing a baseball cap and sunglasses.',
#  "I can't remember what else he was wearing.",
#  'Police: Did he talk directly to you?',
#  'I mean, did he ask you for your money or anything?',
#  'Woman: No, he just told me to get on the ground.',
#  "That's all I know.",
#  "I'm running late for a class.",
#  'Is it okay if I go now?',
#  'Police: I just want to get your name and phone number.',
#  'If you think of anything else, please notify us.']

# %%
# import sys
# import os
# print(sys.path)
# path=[]
# for i in sys.path:

# %% [markdown]
# #tree bank

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(dataset)
# Out:
# ['Police',
#  ':',
#  'I',
#  'understand',
#  'you',
#  'were',
#  'the',
#  'key',
#  'witness',
#  'for',
#  'the',
#  'robbery.',
#  'Woman',
#  ':',
#  'Yes',
#  ',',
#  'I',
#  'was',
#  'the',
#  'only',
#  'other',
#  'person',
#  'in',
#  'the',
#  'bank',
#  'besides',
#  'the',
#  'tellers.',
#  'Police',
#  ':',
#  'Are',
#  'you',
#  'okay',
#  'to',
#  'answer',
#  'some',
#  'questions',
#  'for',
#  'me',
#  '?',
#  'Woman',
#  ':',
#  'Sure.',
#  'I',
#  'do',
#  "n't",
#  'know',
#  'how',
#  'much',
#  'help',
#  'I',
#  "'ll",
#  'be.',
#  'He',
#  'made',
#  'me',
#  'get',
#  'on',
#  'the',
#  'ground',
#  'so',
#  'I',
#  'did',
#  "n't",
#  'get',
#  'a',
#  'very',
#  'good',
#  'look',
#  'at',
#  'him.',
#  'Police',
#  ':',
#  'Was',
#  'he',
#  'carrying',
#  'a',
#  'weapon',
#  '?',
#  'Woman',
#  ':',
#  'Yes',
#  ',',
#  'he',
#  'had',
#  'a',
#  'pistol',
#  'in',
#  'his',
#  'back',
#  'pocket.',
#  'He',
#  'threatened',
#  'to',
#  'use',
#  'it',
#  ',',
#  'but',
#  'I',
#  'doubt',
#  'it',
#  'was',
#  'loaded.',
#  'Police',
#  ':',
#  'What',
#  'makes',
#  'you',
#  'say',
#  'that',
#  '?',
#  'Woman',
#  ':',
#  'He',
#  'was',
#  'just',
#  'a',
#  'kid.',
#  'Probably',
#  'fifteen',
#  'or',
#  'younger.',
#  'Police',
#  ':',
#  'Can',
#  'you',
#  'describe',
#  'him',
#  'for',
#  'me',
#  '?',
#  'Woman',
#  ':',
#  'He',
#  'was',
#  'Asian.',
#  'Probably',
#  'five',
#  'foot',
#  'six.',
#  'He',
#  'was',
#  'wearing',
#  'a',
#  'baseball',
#  'cap',
#  'and',
#  'sunglasses.',
#  'I',
#  'ca',
#  "n't",
#  'remember',
#  'what',
#  'else',
#  'he',
#  'was',
#  'wearing.',
#  'Police',
#  ':',
#  'Did',
#  'he',
#  'talk',
#  'directly',
#  'to',
#  'you',
#  '?',
#  'I',
#  'mean',
#  ',',
#  'did',
#  'he',
#  'ask',
#  'you',
#  'for',
#  'your',
#  'money',
#  'or',
#  'anything',
#  '?',
#  'Woman',
#  ':',
#  'No',
#  ',',
#  'he',
#  'just',
#  'told',
#  'me',
#  'to',
#  'get',
#  'on',
#  'the',
#  'ground.',
#  'That',
#  "'s",
#  'all',
#  'I',
#  'know.',
#  'I',
#  "'m",
#  'running',
#  'late',
#  'for',
#  'a',
#  'class.',
#  'Is',
#  'it',
#  'okay',
#  'if',
#  'I',
#  'go',
#  'now',
#  '?',
#  'Police',
#  ':',
#  'I',
#  'just',
#  'want',
#  'to',
#  'get',
#  'your',
#  'name',
#  'and',
#  'phone',
#  'number.',
#  'If',
#  'you',
#  'think',
#  'of',
#  'anything',
#  'else',
#  ',',
#  'please',
#  'notify',
#  'us',
#  '.']

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer("[\w']+")
tokenizer.tokenize(dataset)
# Out:
# ['Police',
#  'I',
#  'understand',
#  'you',
#  'were',
#  'the',
#  'key',
#  'witness',
#  'for',
#  'the',
#  'robbery',
#  'Woman',
#  'Yes',
#  'I',
#  'was',
#  'the',
#  'only',
#  'other',
#  'person',
#  'in',
#  'the',
#  'bank',
#  'besides',
#  'the',
#  'tellers',
#  'Police',
#  'Are',
#  'you',
#  'okay',
#  'to',
#  'answer',
#  'some',
#  'questions',
#  'for',
#  'me',
#  'Woman',
#  'Sure',
#  'I',
#  "don't",
#  'know',
#  'how',
#  'much',
#  'help',
#  "I'll",
#  'be',
#  'He',
#  'made',
#  'me',
#  'get',
#  'on',
#  'the',
#  'ground',
#  'so',
#  'I',
#  "didn't",
#  'get',
#  'a',
#  'very',
#  'good',
#  'look',
#  'at',
#  'him',
#  'Police',
#  'Was',
#  'he',
#  'carrying',
#  'a',
#  'weapon',
#  'Woman',
#  'Yes',
#  'he',
#  'had',
#  'a',
#  'pistol',
#  'in',
#  'his',
#  'back',
#  'pocket',
#  'He',
#  'threatened',
#  'to',
#  'use',
#  'it',
#  'but',
#  'I',
#  'doubt',
#  'it',
#  'was',
#  'loaded',
#  'Police',
#  'What',
#  'makes',
#  'you',
#  'say',
#  'that',
#  'Woman',
#  'He',
#  'was',
#  'just',
#  'a',
#  'kid',
#  'Probably',
#  'fifteen',
#  'or',
#  'younger',
#  'Police',
#  'Can',
#  'you',
#  'describe',
#  'him',
#  'for',
#  'me',
#  'Woman',
#  'He',
#  'was',
#  'Asian',
#  'Probably',
#  'five',
#  'foot',
#  'six',
#  'He',
#  'was',
#  'wearing',
#  'a',
#  'baseball',
#  'cap',
#  'and',
#  'sunglasses',
#  'I',
#  "can't",
#  'remember',
#  'what',
#  'else',
#  'he',
#  'was',
#  'wearing',
#  'Police',
#  'Did',
#  'he',
#  'talk',
#  'directly',
#  'to',
#  'you',
#  'I',
#  'mean',
#  'did',
#  'he',
#  'ask',
#  'you',
#  'for',
#  'your',
#  'money',
#  'or',
#  'anything',
#  'Woman',
#  'No',
#  'he',
#  'just',
#  'told',
#  'me',
#  'to',
#  'get',
#  'on',
#  'the',
#  'ground',
#  "That's",
#  'all',
#  'I',
#  'know',
#  "I'm",
#  'running',
#  'late',
#  'for',
#  'a',
#  'class',
#  'Is',
#  'it',
#  'okay',
#  'if',
#  'I',
#  'go',
#  'now',
#  'Police',
#  'I',
#  'just',
#  'want',
#  'to',
#  'get',
#  'your',
#  'name',
#  'and',
#  'phone',
#  'number',
#  'If',
#  'you',
#  'think',
#  'of',
#  'anything',
#  'else',
#  'please',
#  'notify',
#  'us']

# %%
from nltk.tokenize import WhitespaceTokenizer
tk=WhitespaceTokenizer()
y=tk.tokenize(dataset)
y
# Out:
# ['Police:',
#  'I',
#  'understand',
#  'you',
#  'were',
#  'the',
#  'key',
#  'witness',
#  'for',
#  'the',
#  'robbery.',
#  'Woman:',
#  'Yes,',
#  'I',
#  'was',
#  'the',
#  'only',
#  'other',
#  'person',
#  'in',
#  'the',
#  'bank',
#  'besides',
#  'the',
#  'tellers.',
#  'Police:',
#  'Are',
#  'you',
#  'okay',
#  'to',
#  'answer',
#  'some',
#  'questions',
#  'for',
#  'me?',
#  'Woman:',
#  'Sure.',
#  'I',
#  "don't",
#  'know',
#  'how',
#  'much',
#  'help',
#  "I'll",
#  'be.',
#  'He',
#  'made',
#  'me',
#  'get',
#  'on',
#  'the',
#  'ground',
#  'so',
#  'I',
#  "didn't",
#  'get',
#  'a',
#  'very',
#  'good',
#  'look',
#  'at',
#  'him.',
#  'Police:',
#  'Was',
#  'he',
#  'carrying',
#  'a',
#  'weapon?',
#  'Woman:',
#  'Yes,',
#  'he',
#  'had',
#  'a',
#  'pistol',
#  'in',
#  'his',
#  'back',
#  'pocket.',
#  'He',
#  'threatened',
#  'to',
#  'use',
#  'it,',
#  'but',
#  'I',
#  'doubt',
#  'it',
#  'was',
#  'loaded.',
#  'Police:',
#  'What',
#  'makes',
#  'you',
#  'say',
#  'that?',
#  'Woman:',
#  'He',
#  'was',
#  'just',
#  'a',
#  'kid.',
#  'Probably',
#  'fifteen',
#  'or',
#  'younger.',
#  'Police:',
#  'Can',
#  'you',
#  'describe',
#  'him',
#  'for',
#  'me?',
#  'Woman:',
#  'He',
#  'was',
#  'Asian.',
#  'Probably',
#  'five',
#  'foot',
#  'six.',
#  'He',
#  'was',
#  'wearing',
#  'a',
#  'baseball',
#  'cap',
#  'and',
#  'sunglasses.',
#  'I',
#  "can't",
#  'remember',
#  'what',
#  'else',
#  'he',
#  'was',
#  'wearing.',
#  'Police:',
#  'Did',
#  'he',
#  'talk',
#  'directly',
#  'to',
#  'you?',
#  'I',
#  'mean,',
#  'did',
#  'he',
#  'ask',
#  'you',
#  'for',
#  'your',
#  'money',
#  'or',
#  'anything?',
#  'Woman:',
#  'No,',
#  'he',
#  'just',
#  'told',
#  'me',
#  'to',
#  'get',
#  'on',
#  'the',
#  'ground.',
#  "That's",
#  'all',
#  'I',
#  'know.',
#  "I'm",
#  'running',
#  'late',
#  'for',
#  'a',
#  'class.',
#  'Is',
#  'it',
#  'okay',
#  'if',
#  'I',
#  'go',
#  'now?',
#  'Police:',
#  'I',
#  'just',
#  'want',
#  'to',
#  'get',
#  'your',
#  'name',
#  'and',
#  'phone',
#  'number.',
#  'If',
#  'you',
#  'think',
#  'of',
#  'anything',
#  'else,',
#  'please',
#  'notify',
#  'us.']

# %% [markdown]
# #Word Frequnecy

# %%
import pandas as pd
import nltk

# %%
text=dataset
token=nltk.tokenize.word_tokenize(text)
fd=nltk.FreqDist(token)
fd.plot(50,cumulative=False)

# %% [markdown]
# #
